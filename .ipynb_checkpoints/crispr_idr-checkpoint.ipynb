# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import rankdata
# %matplotlib inline

# %%
data = pd.read_csv('../GenomeCRISPR_full05112017.csv')

# %%
data.head()

# %%
# get pmids
pmids = data.pubmed.unique()
pmids
# Out:
# array([26472758., 26627737., 24336569., 24717434., 25494202., 27260157.,
#        27013184., 27453484., 24336571., 27383988., 26780180., 27760321.,
#        27661255., 27260156., 27869803.,       nan, 28162770.,   999999.,
#        28145866., 28700943., 29083409.])

# %%
# remove nan and 999999 and meyers pmid
pmids = [26472758., 26627737., 24336569., 24717434., 25494202., 27260157.,
       27013184., 27453484., 24336571., 27383988., 26780180., 27760321.,
       27661255., 27260156., 27869803., 28162770.,
       28145866., 28700943.]
# get meyers pmid
pm1 = 29083409

# %%
# group data for meyers
d1 = data[data['pubmed'] == 29083409]
# d1 = d1.groupby(["sequence", "cellline", "symbol"]).median()['effect'].reset_index()

# try removing cellline
d1 = d1.groupby(["sequence", "symbol"]).median()['effect'].reset_index()

# %%
# get number of celline intersect
for pm2 in pmids:
    d2 = data[data['pubmed'] == pm2]
    print pm2
    print(len(np.intersect1d(d1.cellline.unique(),d2.cellline.unique())))
    print "################"
# Out:
# 26472758.0
# 0
# ################
# 26627737.0
# 1
# ################
# 24336569.0
# 0
# ################
# 24717434.0
# 0
# ################
# 25494202.0
# 0
# ################
# 27260157.0
# 4
# ################
# 27013184.0
# 0
# ################
# 27453484.0
# 0
# ################
# 24336571.0
# 0
# ################
# 27383988.0
# 0
# ################
# 26780180.0
# 0
# ################
# 27760321.0
# 3
# ################
# 27661255.0
# 0
# ################
# 27260156.0
# 1
# ################
# 27869803.0
# 2
# ################
# 28162770.0
# 9
# ################
# 28145866.0
# 0
# ################
# 28700943.0
# 2
# ################

# %%
# get number of celline intersect
for pm2 in pmids:
    d2 = data[data['pubmed'] == pm2]
    print pm2
    print(len(np.intersect1d(d1.cellline.unique(),d2.cellline.unique())))
    print "################"
# Out:
# 26472758.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-edf0b6589e9a> in <module>()
#       3     d2 = data[data['pubmed'] == pm2]
#       4     print pm2
# ----> 5     print(len(np.intersect1d(d1.cellline.unique(),d2.cellline.unique())))
#       6     print "################"
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cellline'

# %%
# choose just one with highest cellline intersect for now
# pmids= [28162770.0]
for pm2 in pmids:
    d2 = data[data['pubmed'] == pm2]
#     d2 = d2.groupby(["sequence", "cellline", "symbol"]).median()['effect'].reset_index()
    
    # try removing cellline
    d2 = d2.groupby(["sequence", "symbol"]).median()['effect'].reset_index()
    
#     joined = d2.merge(d1, left_on=["sequence", "cellline", "symbol"], right_on=["sequence", "cellline", "symbol"], how="inner")
    
    # try removing cellline
    joined = d2.merge(d1, left_on=["sequence", "symbol"], right_on=["sequence", "symbol"], how="inner")
    
    nrows = joined.shape[0]
    
    # rank effect
#     eff1 = rankdata(joined['effect_x'])
#     eff2 = rankdata(joined['effect_y'])
    
    # try dense method
    eff1 = rankdata(joined['effect_x'], method="dense")
    eff2 = rankdata(joined['effect_y'], method="dense")

    corrGen = np.dot(eff1/float(nrows), eff2/float(nrows))/float(nrows)
    print pm2
    print corrGen
    
    plt.scatter(eff1, eff2, alpha=0.02)
    plt.show()
    
    print ###################
# Out:
# 26472758.0
# 8.562722057690333e-07
# 26627737.0
# 5.338147859127108e-06
# 24336569.0
# 1.1699936595338269e-05
# 24717434.0
# 0.421875
# 25494202.0
# 0.057588569762356025
# 27260157.0
# 3.9401655382566154e-05
# 27013184.0
# 0.0008629829901946512
# 27453484.0
# 7.041063089448685e-08
# 24336571.0
# 3.1603196796510134e-05
# 27383988.0
# 1.3985439413301809e-05
# 26780180.0
# 6.2086932809909e-08
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in double_scalars
# 27760321.0
# nan
# 27661255.0
# 6.426339700456394e-05
# 27260156.0
# 5.168154835504854e-06
# 27869803.0
# 5.367743420603659e-06
# 28162770.0
# 7.906859656607085e-07
# 28145866.0
# 8.51653678065934e-06
# 28700943.0
# 5.3243198937060274e-06

# %%
joined.head()
# Out:
#                   sequence   symbol  effect_x  effect_y
# 0  AAAACACGCAATTTGTGCAGCGG  CXorf58       6.0       0.0
# 1  AAAACTGTCCATAGTGACCGGGG     NPM3       7.0      -1.0
# 2  AAAAGAATCAGATAGACCCGTGG    BHMT2      -2.0      -2.0
# 3  AAACAACGACAGCGAGACCGCGG   SPACA1       6.0       5.0
# 4  AAACACATCTCTCACCGCGGAGG    GDPD1       2.0       1.0

# %%
joined_seq = joined.groupby(["sequence"])

# %%
joined_seq.head()
# Out:
#                      sequence     symbol  effect_x  effect_y
# 0     AAAACACGCAATTTGTGCAGCGG    CXorf58       6.0       0.0
# 1     AAAACTGTCCATAGTGACCGGGG       NPM3       7.0      -1.0
# 2     AAAAGAATCAGATAGACCCGTGG      BHMT2      -2.0      -2.0
# 3     AAACAACGACAGCGAGACCGCGG     SPACA1       6.0       5.0
# 4     AAACACATCTCTCACCGCGGAGG      GDPD1       2.0       1.0
# 5     AAACTGCTGCTATCTCCCGGCGG     MRPL10      -6.0      -7.0
# 6     AAACTTCCTGGCTTACACGGCGG      NIPA1       4.0       3.0
# 7     AAACTTGTGCAAGCAGAAGGAGG        DCN       5.0       4.0
# 8     AAAGAACCTACAGAGAACTGCGG     MAPK14       0.0      -2.0
# 9     AAAGAGCACTGGACTCCGGAAGG       SAT1       8.0       6.0
# 10    AAAGATGACGGAGTTGACCATGG    PPIAL4G      -8.0      -9.0
# 11    AAAGCCGATGAAGAAGAAGGCGG     CX3CR1      -9.0      -4.0
# 12    AAAGCGGAACCGGATCACCGAGG     TMEM57       1.0      -1.0
# 13    AAAGCTCTACAAGATGGCGGCGG    SUV39H2       3.0       1.0
# 14    AAAGGGTGTGTCGATGACAGCGG      VWC2L       4.0      -2.0
# 15    AAAGGTAGATACACTCACAGAGG      CCKAR       1.0       3.0
# 16    AAAGTCGGGATCCTACACCTGGG     XAGE1A       2.0       1.0
# 17    AAAGTCTTCTCGGGGAGTGGCGG       NSL1      -6.0      -5.0
# 18    AAATCACAACGACATCTAGGTGG      SEMG1       9.0       3.0
# 19    AAATCTGTACAAACCAACCGAGG       NEK5       0.0       1.0
# 20    AACAACTACCATGGTGGCCAGGG  KRTAP22-1       7.0       4.0
# 21    AACAAGCTCCCCAGTAACCGGGG      TESK1       1.0       0.0
# 22    AACAGCACAGGACCACCAGGAGG       GYG1       1.0       4.0
# 23    AACAGCCTCCAGCACCCGGGAGG      MPZL2      -3.0       0.0
# 24    AACAGCTACTACTTGTCCAGAGG      CDKL4      -4.0       0.0
# 25    AACATGGGAGAAATTGCATGCGG   ATP6V1C1      -3.0      -6.0
# 26    AACCCAGCCACACTGAGCGGCGG      LPIN3       0.0      -6.0
# 27    AACCCGAACCCACCAACCAGGGG     MS4A6E       0.0       1.0
# 28    AACCGGCATGGCCAAAGCCGCGG     HSPA1A       1.0      -5.0
# 29    AACCTGGAGAACCGCTTCAGCGG      PGAM1      -8.0      -9.0
# ...                       ...        ...       ...       ...
# 4952  TTTAGTGTGAGACTGCACCGTGG       GBP1       5.0       4.0
# 4953  TTTATATCAGCACTTTGCCGAGG    KBTBD12       5.0      -3.0
# 4954  TTTATCACAGGTGCAAGCCGTGG      HSDL2       7.0       1.0
# 4955  TTTCAGATCAACTCCAACGACGG       SGCG       8.0       0.0
# 4956  TTTCAGCTCGAGGAACCTGGTGG      GTSF1       4.0      -3.0
# 4957  TTTCAGCTGCTTCAACAGAGTGG       ASNS       0.0       4.0
# 4958  TTTCAGGCCCTAGACACTGGTGG    SPINK14       4.0       2.0
# 4959  TTTCAGTTGTGCAACCACTGTGG      EIF3E      -8.0      -8.0
# 4960  TTTCCAGACGAAGTTTACTGAGG       MSTN       4.0      -1.0
# 4961  TTTCCCACTAAAACATGCGGTGG       PHKB       0.0       1.0
# 4962  TTTCCGGCCATTTAAAGGGGAGG     POLR2G      -7.0      -6.0
# 4963  TTTCTACAGGTCACCAACTGCGG      RGS21       3.0       6.0
# 4964  TTTCTCCACATCATAGCCGGCGG   HIST1H1C       2.0      -2.0
# 4965  TTTCTCTTCCTCCTCACCAGGGG     CLPSL1      -2.0       2.0
# 4966  TTTCTGCCTGAAGAAGCTGGTGG   ATP6V1G3       2.0       4.0
# 4967  TTTGAGATACAGGTGACAGGAGG       CD1A      -3.0       4.0
# 4968  TTTGAGTTAGAGGAGACTGGAGG     CYP7A1      -5.0      -1.0
# 4969  TTTGATATCAAGCATGGCGAGGG    CCDC125       3.0      -6.0
# 4970  TTTGCAAGGCCCACACCACGTGG        TXN      -9.0      -9.0
# 4971  TTTGCCGTCAAAGTGCGCGGCGG     NMRAL1       1.0       0.0
# 4972  TTTGGAGAATCATCAAGCAGTGG      TPPP2       5.0       2.0
# 4973  TTTGGATGATCTTGACCCCGAGG      TMOD3       5.0       3.0
# 4974  TTTGGCGCGGGGCACACAGGAGG     SPRR2F      -8.0      -8.0
# 4975  TTTGGCTACGAGCTGAGCAGCGG      WNT16       4.0       0.0
# 4976  TTTGGTAGCAATGACTGATGTGG       PKIA       0.0       2.0
# 4977  TTTGGTGCTAGGCTTGGCCGTGG      IFNL1       5.0       2.0
# 4978  TTTGTAGGAGGAAGAGGAAGAGG      UQCRH      -9.0      -9.0
# 4979  TTTGTCATTGCAGGTCATGGAGG   DEFB103A       4.0       4.0
# 4980  TTTGTGTTGTAGAATGCCAGAGG       POMP      -8.0      -8.0
# 4981  TTTGTTGGCACAAATACGGGCGG     RPL10L       2.0       2.0
#
# [4982 rows x 4 columns]

# %%
# doench
d2 = data[data['pubmed'] == 26780180]
d2 = d2.groupby(["sequence", "cellline", "symbol"]).median()['effect'].reset_index()
